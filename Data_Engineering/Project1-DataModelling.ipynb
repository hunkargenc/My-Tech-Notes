# %% [markdown]
# # Project 1 - Data Modelling

# %% [markdown]
# **Step 1:** Select a open source dataset

# %% [markdown]
# **Monthly Electricity Production in GWh [2010-2022]**
#
# https://www.kaggle.com/datasets/ccanb23/iea-monthly-electricity-statistics?resource=download

# %% [markdown]
# **Step 2:** Load data

# %%
import pandas as pd

# %%
ElectricityProduction = pd.read_csv("./datasets/data.csv")

# %%
ElectricityProduction.head()
# Out:
#      COUNTRY CODE_TIME          TIME  YEAR  MONTH MONTH_NAME  \
# 0  Australia   JAN2010  January 2010  2010      1    January
# 1  Australia   JAN2010  January 2010  2010      1    January
# 2  Australia   JAN2010  January 2010  2010      1    January
# 3  Australia   JAN2010  January 2010  2010      1    January
# 4  Australia   JAN2010  January 2010  2010      1    January
#
#                    PRODUCT      VALUE  DISPLAY_ORDER  yearToDate  \
# 0                    Hydro    990.728              1   16471.891
# 1                     Wind    409.469              2    4940.909
# 2                    Solar     49.216              3     908.238
# 3               Geothermal      0.083              4       0.996
# 4  Total combustible fuels  19289.730              7  214302.969
#
#    previousYearToDate     share
# 0                 NaN  0.047771
# 1                 NaN  0.019744
# 2                 NaN  0.002373
# 3                 NaN  0.000004
# 4                 NaN  0.930108

# %% [markdown]
# **Step 3:** Filter by country Türkiye

# %%
ElectricityProduction.COUNTRY.unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Chile',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'IEA Total', 'Iceland', 'Ireland',
#        'Italy', 'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'OECD Americas',
#        'OECD Asia Oceania', 'OECD Europe', 'OECD Total', 'Poland',
#        'Portugal', 'Republic of Turkiye', 'Slovak Republic', 'Slovenia',
#        'Spain', 'Sweden', 'Switzerland', 'United Kingdom',
#        'United States', 'Colombia', 'Argentina', 'Brazil', 'Bulgaria',
#        'Croatia', 'Cyprus', 'India', 'Malta', 'North Macedonia',
#        'Romania', 'Serbia', 'Costa Rica'], dtype=object)

# %%
ElectricityProductionTurkiye = ElectricityProduction[ElectricityProduction.COUNTRY == 'Republic of Turkiye']

# %%
ElectricityProductionTurkiye.COUNTRY.unique()
# Out:
# array(['Republic of Turkiye'], dtype=object)

# %%
ElectricityProductionTurkiye.head()
# Out:
#                  COUNTRY CODE_TIME          TIME  YEAR  MONTH MONTH_NAME  \
# 763  Republic of Turkiye   JAN2010  January 2010  2010      1    January
# 764  Republic of Turkiye   JAN2010  January 2010  2010      1    January
# 765  Republic of Turkiye   JAN2010  January 2010  2010      1    January
# 766  Republic of Turkiye   JAN2010  January 2010  2010      1    January
# 767  Republic of Turkiye   JAN2010  January 2010  2010      1    January
#
#               PRODUCT     VALUE  DISPLAY_ORDER  yearToDate  \
# 763             Hydro  4186.449              1   51423.001
# 764              Wind   240.631              2    2908.000
# 765             Solar     0.000              3       0.000
# 766        Geothermal    45.985              4     567.002
# 767  Other renewables     0.000              5       0.000
#
#      previousYearToDate     share
# 763                 NaN  0.248737
# 764                 NaN  0.014297
# 765                 NaN  0.000000
# 766                 NaN  0.002732
# 767                 NaN  0.000000

# %%
ElectricityProductionTurkiye.tail()
# Out:
#                     COUNTRY CODE_TIME           TIME  YEAR  MONTH MONTH_NAME  \
# 181704  Republic of Turkiye   DEC2022  December 2022  2022     12   December
# 181705  Republic of Turkiye   DEC2022  December 2022  2022     12   December
# 181706  Republic of Turkiye   DEC2022  December 2022  2022     12   December
# 181707  Republic of Turkiye   DEC2022  December 2022  2022     12   December
# 181708  Republic of Turkiye   DEC2022  December 2022  2022     12   December
#
#                             PRODUCT         VALUE  DISPLAY_ORDER  \
# 181704               Non-renewables  17118.575448             23
# 181705                       Others    111.193449             24
# 181706  Other renewables aggregated   1529.258050             25
# 181707                   Low carbon   8261.257815             26
# 181708                 Fossil fuels  17118.575448             27
#
#            yearToDate  previousYearToDate     share
# 181704  179285.576235       202133.138342  0.677125
# 181705    1971.873925         1920.760240  0.004398
# 181706   16594.174350        14784.034557  0.060490
# 181707  134811.760715       115941.722700  0.326774
# 181708  179285.576235       202133.138342  0.677125

# %%
ElectricityProductionTurkiye.describe()
# Out:
#               YEAR        MONTH         VALUE  DISPLAY_ORDER     yearToDate  \
# count  4094.000000  4094.000000   4094.000000    4094.000000    4094.000000
# mean   2015.941622     6.498046   5630.632681      14.136541   67567.592166
# std       3.751734     3.452922   7502.692159       7.799476   89138.955248
# min    2010.000000     1.000000   -802.949000       1.000000   -6201.998000
# 25%    2013.000000     3.250000     75.665750       8.000000    1013.134000
# 50%    2016.000000     6.000000    853.058865      14.000000   10615.054808
# 75%    2019.000000     9.000000   9580.618348      21.000000  114536.729989
# max    2022.000000    12.000000  31016.187000      27.000000  316669.868328
#
#        previousYearToDate        share
# count         3742.000000  4094.000000
# mean         35955.383994     0.256941
# std          56896.227695     0.337522
# min          -6201.998000    -0.041162
# 25%            364.833969     0.003737
# 50%           5014.354000     0.037542
# 75%          50722.432000     0.425814
# max         316669.868328     1.041162

# %% [markdown]
# ## Load to Database

# %% [markdown]
# **Step 4:** Create Database

# %%
import psycopg2

# %%
# Create Database
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=153624")
    cur = conn.cursor()
    conn.set_session(autocommit=True)
    cur.execute("CREATE DATABASE ElectricityProduction")
except psycopg2.Error as e:
    print(e)
finally:
    conn.close()
    cur.close()

# %%
ElectricityProductionTurkiye.columns
# Out:
# Index(['COUNTRY', 'CODE_TIME', 'TIME', 'YEAR', 'MONTH', 'MONTH_NAME',
#        'PRODUCT', 'VALUE', 'DISPLAY_ORDER', 'yearToDate', 'previousYearToDate',
#        'share'],
#       dtype='object')

# %%
ElectricityProductionTurkiye.dtypes
# Out:
# COUNTRY                object
# CODE_TIME              object
# TIME                   object
# YEAR                    int64
# MONTH                   int64
# MONTH_NAME             object
# PRODUCT                object
# VALUE                 float64
# DISPLAY_ORDER           int64
# yearToDate            float64
# previousYearToDate    float64
# share                 float64
# dtype: object

# %%
from sqlalchemy import create_engine, text

# %%
def map_data_types(col_type):
    if col_type == 'object':
        return 'varchar'
    elif col_type == 'int64':
        return 'int'
    elif col_type == 'float64':
        return 'float'
    else:
        return 'varchar'

def create_table(table_name, dataframe):
    try:
        engine = create_engine('postgresql://postgres:153624@127.0.0.1/ElectricityProduction')
        conn = engine.connect()

        columns = ', '.join([f"{column.lower()} {map_data_types(str(dataframe.dtypes[column]))}" for column in dataframe.columns])
        create_table_query = f"CREATE TABLE IF NOT EXISTS {table_name} (id SERIAL PRIMARY KEY, {columns});"

        conn.execute(text(create_table_query))
        conn.commit()
        print(f"Table '{table_name}' created successfully.")

    except Exception as e:
        print(f"Error: Issue creating table '{table_name}'")
        print(e)
    finally:
        conn.close()

create_table("TurkiyeDatas", ElectricityProductionTurkiye)
# Out:
# Table 'TurkiyeDatas' created successfully.

# %% [markdown]
# **Step 5:** Insert dataframe datas

# %%
def insert_datas(table_name, dataframe):
    try:
        engine = create_engine('postgresql://postgres:153624@127.0.0.1/ElectricityProduction')
        conn = engine.connect()
        
        lowercase_columns = [column.lower() for column in dataframe.columns]

        insert_query = text(f"INSERT INTO {table_name} ({', '.join(lowercase_columns)}) VALUES {', '.join([str(tuple(row)).replace('nan', 'NULL') for row in dataframe.itertuples(index=False)])};")
        conn.execute(insert_query)
        conn.commit()

        print(f"{len(dataframe)} rows inserted successfully.")

    except Exception as e:
        print(f"Error: Issue inserting data into table '{table_name}'")
        print(e)
    finally:
        conn.close()

# %%
insert_datas("TurkiyeDatas", ElectricityProductionTurkiye)
# Out:
# 4094 rows inserted successfully.

# %% [markdown]
# **Step 6:** Check table

# %%
def check_table():
    try:
        engine = create_engine('postgresql://postgres:153624@127.0.0.1/ElectricityProduction')
        conn = engine.connect()
        cur = conn.connection.cursor()

        query = f"SELECT * FROM turkiyedatas;"
        cur.execute(query)

        rows = cur.fetchall()
        for row in rows:
            print(row)
    except Exception as e:
        print(e)
    finally:
        cur.close()
        conn.close()

# %%
check_table()
# Out:
# (1, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Hydro', 4186.449, 1, 51423.001, None, 0.2487374925671946)
# (2, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Wind', 240.631, 2, 2908.0, None, 0.0142970693238915)
# (3, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (4, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Geothermal', 45.985, 4, 567.002, None, 0.0027321946584569)
# (5, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (6, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (7, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Total combustible fuels', 12348.644, 7, 148039.001, None, 0.7336935778185601)
# (8, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Coal', 4316.608, 8, 52332.776, None, 0.2564708779004577)
# (9, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Oil', 169.861, 9, 2072.51, None, 0.0100922761091694)
# (10, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Natural gas', 7831.162, 10, 93304.775, None, 0.4652877891901937)
# (11, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Combustible renewables', 29.758, 11, 315.629, None, 0.0017680689060859)
# (12, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Other combustible non-renewables', 1.255, 12, 13.309, None, 7.456571265333205e-05)
# (13, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Not specified', 9.083, 13, 108.996, None, 0.0005396656318965)
# (14, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Net electricity production', 16830.792, 14, 203046.001, None, 1.0)
# (15, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Total imports', 62.229, 15, 1144.001, None, 0.0036973304643061)
# (16, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Total exports', 127.369, 16, 1918.001, None, 0.0075676177330217)
# (17, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Electricity supplied', 16765.652, 17, 202272.001, None, 0.9961297127312844)
# (18, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (19, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Distribution losses', 2497.56, 19, 30222.0, None, 0.1483923038202836)
# (20, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Final consumption', 14268.091, 20, 172050.001, None, 0.8477373494960903)
# (21, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Electricity trade', 65.14, 21, 774.0, None, 0.0038702872687155)
# (22, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Renewables', 4502.823, 22, 55213.632, None, 0.2675348254556292)
# (23, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Non-renewables', 12327.969, 23, 147832.366, None, 0.7324651745443707)
# (24, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Others', 180.199, 24, 2194.815, None, 0.0107065074537193)
# (25, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Other renewables aggregated', 75.743, 25, 882.631, None, 0.0045002635645428)
# (26, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Low carbon', 4511.906, 26, 55322.628, None, 0.2680744910875257)
# (27, 'Republic of Turkiye', 'JAN2010', 'January 2010', 2010, 1, 'January', 'Fossil fuels', 12327.969, 27, 147832.366, None, 0.7324651745443707)
# (28, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Hydro', 4336.211, 1, 51423.001, None, 0.2832607632709147)
# (29, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Wind', 205.932, 2, 2908.0, None, 0.0134524024550249)
# (30, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (31, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Geothermal', 40.105, 4, 567.002, None, 0.0026198385897226)
# (32, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (33, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (34, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Total combustible fuels', 10716.864, 7, 148039.001, None, 0.7000736533601774)
# (35, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Coal', 3919.064, 8, 52332.776, None, 0.2560108490909608)
# (36, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Oil', 142.795, 9, 2072.51, None, 0.0093280102585575)
# (37, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Natural gas', 6617.976, 10, 93304.775, None, 0.4323158935459079)
# (38, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Combustible renewables', 35.531, 11, 315.629, None, 0.0023210443817837)
# (39, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Other combustible non-renewables', 1.498, 12, 13.309, None, 9.785608296732568e-05)
# (40, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Not specified', 9.083, 13, 108.996, None, 0.0005933423241603)
# (41, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Net electricity production', 15308.195, 14, 203046.001, None, 1.0)
# (42, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Total imports', 57.793, 15, 1144.001, None, 0.0037752981327974)
# (43, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Total exports', 134.613, 16, 1918.001, None, 0.0087935252980511)
# (44, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Electricity supplied', 15231.375, 17, 202272.001, None, 0.9949817728347464)
# (45, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (46, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Distribution losses', 2267.13, 19, 30222.0, None, 0.1480991063936669)
# (47, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Final consumption', 12964.245, 20, 172050.001, None, 0.8468826664410795)
# (48, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Electricity trade', 76.82, 21, 774.0, None, 0.0050182271652536)
# (49, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Renewables', 4617.779, 22, 55213.632, None, 0.301654048697446)
# (50, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Non-renewables', 10690.416, 23, 147832.366, None, 0.698345951302554)
# (51, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Others', 153.376, 24, 2194.815, None, 0.0100192086656852)
# (52, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Other renewables aggregated', 75.636, 25, 882.631, None, 0.0049408829715064)
# (53, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Low carbon', 4626.862, 26, 55322.628, None, 0.3022473910216064)
# (54, 'Republic of Turkiye', 'FEB2010', 'February 2010', 2010, 2, 'February', 'Fossil fuels', 10690.416, 27, 147832.366, None, 0.698345951302554)
# (55, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Hydro', 5335.623, 1, 51423.001, None, 0.3228481551639447)
# (56, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Wind', 187.762, 2, 2908.0, None, 0.0113611129028217)
# (57, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (58, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Geothermal', 40.632, 4, 567.002, None, 0.002458563178212)
# (59, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (60, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (61, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Total combustible fuels', 10953.626, 7, 148039.001, None, 0.6627825741166158)
# (62, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Coal', 3823.349, 8, 52332.776, None, 0.231343400985773)
# (63, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Oil', 168.913, 9, 2072.51, None, 0.0102205966263372)
# (64, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Natural gas', 6930.267, 10, 93304.775, None, 0.4193369576043071)
# (65, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Combustible renewables', 29.839, 11, 315.629, None, 0.0018054997704929)
# (66, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Other combustible non-renewables', 1.258, 12, 13.309, None, 7.611912970542382e-05)
# (67, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Not specified', 9.083, 13, 108.996, None, 0.0005495946384056)
# (68, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Net electricity production', 16526.726, 14, 203046.001, None, 1.0)
# (69, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Total imports', 49.285, 15, 1144.001, None, 0.0029821393541588)
# (70, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Total exports', 87.495, 16, 1918.001, None, 0.0052941520298696)
# (71, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Electricity supplied', 16488.516, 17, 202272.001, None, 0.9976879873242892)
# (72, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (73, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Distribution losses', 2445.956, 19, 30222.0, None, 0.1480000334004448)
# (74, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Final consumption', 14042.56, 20, 172050.001, None, 0.8496879539238443)
# (75, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Electricity trade', 38.21, 21, 774.0, None, 0.0023120126757108)
# (76, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Renewables', 5593.856, 22, 55213.632, None, 0.3384733310154715)
# (77, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Non-renewables', 10932.87, 23, 147832.366, None, 0.6615266689845285)
# (78, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Others', 179.254, 24, 2194.815, None, 0.0108463103944483)
# (79, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Other renewables aggregated', 70.471, 25, 882.631, None, 0.004264062948705)
# (80, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Low carbon', 5602.939, 26, 55322.628, None, 0.3390229256538772)
# (81, 'Republic of Turkiye', 'MAR2010', 'March 2010', 2010, 3, 'March', 'Fossil fuels', 10932.87, 27, 147832.366, None, 0.6615266689845285)
# (82, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Hydro', 5564.359, 1, 51423.001, None, 0.3530752302487014)
# (83, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Wind', 185.401, 2, 2908.0, None, 0.0117642482743006)
# (84, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (85, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Geothermal', 49.144, 4, 567.002, None, 0.0031183338665499)
# (86, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (87, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (88, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Total combustible fuels', 9951.71, 7, 148039.001, None, 0.6314657806259992)
# (89, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Coal', 3030.823, 8, 52332.776, None, 0.1923147892808605)
# (90, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Oil', 176.262, 9, 2072.51, None, 0.0111843513752611)
# (91, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Natural gas', 6724.458, 10, 93304.775, None, 0.4266869834688456)
# (92, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Combustible renewables', 19.351, 11, 315.629, None, 0.0012278788590999)
# (93, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Other combustible non-renewables', 0.816, 12, 13.309, None, 5.177764193197103e-05)
# (94, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Not specified', 9.083, 13, 108.996, None, 0.0005763435314559)
# (95, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Net electricity production', 15759.698, 14, 203046.001, None, 1.0)
# (96, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Total imports', 35.611, 15, 1144.001, None, 0.0022596245181855)
# (97, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Total exports', 77.168, 16, 1918.001, None, 0.0048965405301548)
# (98, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Electricity supplied', 15718.141, 17, 202272.001, None, 0.9973630839880306)
# (99, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (100, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Distribution losses', 2332.359, 19, 30222.0, None, 0.1479951582828554)
# (101, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Final consumption', 13385.783, 20, 172050.001, None, 0.8493679891581678)
# (102, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Electricity trade', 41.557, 21, 774.0, None, 0.0026369160119692)
# (103, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Renewables', 5818.255, 22, 55213.632, None, 0.3691856912486521)
# (104, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Non-renewables', 9941.442, 23, 147832.366, None, 0.6308142452983553)
# (105, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Others', 186.161, 24, 2194.815, None, 0.011812472548649)
# (106, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Other renewables aggregated', 68.495, 25, 882.631, None, 0.0043462127256499)
# (107, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Low carbon', 5827.338, 26, 55322.628, None, 0.369762034780108)
# (108, 'Republic of Turkiye', 'APR2010', 'April 2010', 2010, 4, 'April', 'Fossil fuels', 9941.442, 27, 147832.366, None, 0.6308142452983553)
# (109, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Hydro', 5043.787, 1, 51423.001, None, 0.3130668407931403)
# (110, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Wind', 125.448, 2, 2908.0, None, 0.0077865320331365)
# (111, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (112, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Geothermal', 47.828, 4, 567.002, None, 0.0029686743039415)
# (113, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (114, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (115, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Total combustible fuels', 10884.749, 7, 148039.001, None, 0.6756141728935605)
# (116, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Coal', 3672.434, 8, 52332.776, None, 0.2279472369474197)
# (117, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Oil', 171.56, 9, 2072.51, None, 0.0106486945635236)
# (118, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Natural gas', 7019.147, 10, 93304.775, None, 0.435677037185085)
# (119, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Combustible renewables', 20.733, 11, 315.629, None, 0.001286893124187)
# (120, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Other combustible non-renewables', 0.874, 12, 13.309, None, 5.424900354697861e-05)
# (121, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Not specified', 9.083, 13, 108.996, None, 0.000563779976221)
# (122, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Net electricity production', 16110.895, 14, 203046.001, None, 1.0)
# (123, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Total imports', 35.49, 15, 1144.001, None, 0.0022028571348767)
# (124, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Total exports', 114.747, 16, 1918.001, None, 0.0071223231235756)
# (125, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Electricity supplied', 16031.638, 17, 202272.001, None, 0.995080534011301)
# (126, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (127, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Distribution losses', 2384.219, 19, 30222.0, None, 0.1479879919768578)
# (128, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Final consumption', 13647.418, 20, 172050.001, None, 0.847092479964645)
# (129, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Electricity trade', 79.257, 21, 774.0, None, 0.0049194659886989)
# (130, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Renewables', 5237.796, 22, 55213.632, None, 0.3251089402544055)
# (131, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Non-renewables', 10873.098, 23, 147832.366, None, 0.6748909976757964)
# (132, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Others', 181.517, 24, 2194.815, None, 0.0112667235432916)
# (133, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Other renewables aggregated', 68.561, 25, 882.631, None, 0.0042555674281286)
# (134, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Low carbon', 5246.879, 26, 55322.628, None, 0.3256727202306265)
# (135, 'Republic of Turkiye', 'MAY2010', 'May 2010', 2010, 5, 'May', 'Fossil fuels', 10873.098, 27, 147832.366, None, 0.6748909976757964)
# (136, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Hydro', 4344.797, 1, 51423.001, None, 0.2600117115464657)
# (137, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Wind', 162.508, 2, 2908.0, None, 0.0097251915843232)
# (138, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (139, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Geothermal', 47.74, 4, 567.002, None, 0.0028569710182612)
# (140, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (141, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (142, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Total combustible fuels', 12145.877, 7, 148039.001, None, 0.7268625592870858)
# (143, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Coal', 4836.581, 8, 52332.776, None, 0.289442223386528)
# (144, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Oil', 167.451, 9, 2072.51, None, 0.0100210023874918)
# (145, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Natural gas', 7120.407, 10, 93304.775, None, 0.4261163895522473)
# (146, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Combustible renewables', 20.57, 11, 315.629, None, 0.0012309990332139)
# (147, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Other combustible non-renewables', 0.867, 12, 13.309, None, 5.188508321810795e-05)
# (148, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Not specified', 9.083, 13, 108.996, None, 0.0005435665638639)
# (149, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Net electricity production', 16710.005, 14, 203046.001, None, 1.0)
# (150, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Total imports', 28.319, 15, 1144.001, None, 0.0016947331852982)
# (151, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Total exports', 155.124, 16, 1918.001, None, 0.009283300633363)
# (152, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Electricity supplied', 16583.2, 17, 202272.001, None, 0.9924114325519352)
# (153, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (154, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Distribution losses', 2469.613, 19, 30222.0, None, 0.147792475226668)
# (155, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Final consumption', 14113.587, 20, 172050.001, None, 0.844618957325267)
# (156, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Electricity trade', 126.805, 21, 774.0, None, 0.0075885674480647)
# (157, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Renewables', 4575.615, 22, 55213.632, None, 0.2738248731822641)
# (158, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Non-renewables', 12134.389, 23, 147832.366, None, 0.7261750669733491)
# (159, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Others', 177.401, 24, 2194.815, None, 0.0106164540345738)
# (160, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Other renewables aggregated', 68.31, 25, 882.631, None, 0.0040879700514751)
# (161, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Low carbon', 4584.698, 26, 55322.628, None, 0.2743684397461281)
# (162, 'Republic of Turkiye', 'JUN2010', 'June 2010', 2010, 6, 'June', 'Fossil fuels', 12134.389, 27, 147832.366, None, 0.7261750669733491)
# (163, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Hydro', 4545.878, 1, 51423.001, None, 0.2412613392157532)
# (164, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Wind', 299.557, 2, 2908.0, None, 0.0158982539767792)
# (165, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (166, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Geothermal', 46.073, 4, 567.002, None, 0.0024452116140572)
# (167, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (168, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (169, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Total combustible fuels', 13941.542, 7, 148039.001, None, 0.7399131902907802)
# (170, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Coal', 5215.199, 8, 52332.776, None, 0.2767839117144492)
# (171, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Oil', 180.213, 9, 2072.51, None, 0.0095643635231936)
# (172, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Natural gas', 8522.573, 10, 93304.775, None, 0.4523146849836313)
# (173, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Combustible renewables', 22.603, 11, 315.629, None, 0.0011995988564351)
# (174, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Other combustible non-renewables', 0.953, 12, 13.309, None, 5.057814052040395e-05)
# (175, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Not specified', 9.083, 13, 108.996, None, 0.0004820579751803)
# (176, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Net electricity production', 18842.132, 14, 203046.001, None, 1.0)
# (177, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Total imports', 55.605, 15, 1144.001, None, 0.002951099164362)
# (178, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Total exports', 166.455, 16, 1918.001, None, 0.0088341913749463)
# (179, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Electricity supplied', 18731.282, 17, 202272.001, None, 0.9941169077894156)
# (180, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (181, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Distribution losses', 2789.784, 19, 30222.0, None, 0.1480609519135095)
# (182, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Final consumption', 15941.498, 20, 172050.001, None, 0.8460559558759061)
# (183, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Electricity trade', 110.85, 21, 774.0, None, 0.0058830922105842)
# (184, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Renewables', 4914.111, 22, 55213.632, None, 0.2608044036630249)
# (185, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Non-renewables', 13928.021, 23, 147832.366, None, 0.739195596336975)
# (186, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Others', 190.249, 24, 2194.815, None, 0.0100969996388943)
# (187, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Other renewables aggregated', 68.676, 25, 882.631, None, 0.0036448104704924)
# (188, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Low carbon', 4923.194, 26, 55322.628, None, 0.2612864616382053)
# (189, 'Republic of Turkiye', 'JUL2010', 'July 2010', 2010, 7, 'July', 'Fossil fuels', 13928.021, 27, 147832.366, None, 0.739195596336975)
# (190, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Hydro', 4685.556, 1, 51423.001, None, 0.2363461001745424)
# (191, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Wind', 285.595, 2, 2908.0, None, 0.0144058174695486)
# (192, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (193, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Geothermal', 45.722, 4, 567.002, None, 0.0023062826251954)
# (194, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (195, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (196, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Total combustible fuels', 14799.021, 7, 148039.001, None, 0.7464836403088893)
# (197, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Coal', 5528.464, 8, 52332.776, None, 0.2788635769917917)
# (198, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Oil', 210.598, 9, 2072.51, None, 0.010622862261076)
# (199, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Natural gas', 9037.675, 10, 93304.775, None, 0.4558731644430154)
# (200, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Combustible renewables', 21.383, 11, 315.629, None, 0.0010785888931926)
# (201, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Other combustible non-renewables', 0.902, 12, 13.309, None, 4.549816123368013e-05)
# (202, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Not specified', 9.083, 13, 108.996, None, 0.0004581594218242)
# (203, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Net electricity production', 19824.977, 14, 203046.001, None, 1.0)
# (204, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Total imports', 47.826, 15, 1144.001, None, 0.0024124113737937)
# (205, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Total exports', 177.428, 16, 1918.001, None, 0.0089497203451988)
# (206, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Electricity supplied', 19695.375, 17, 202272.001, None, 0.993462691028595)
# (207, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (208, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Distribution losses', 2937.841, 19, 30222.0, None, 0.1481888730564479)
# (209, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Final consumption', 16757.535, 20, 172050.001, None, 0.8452738684135674)
# (210, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Electricity trade', 129.602, 21, 774.0, None, 0.0065373089714051)
# (211, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Renewables', 5038.256, 22, 55213.632, None, 0.2541367891624793)
# (212, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Non-renewables', 14786.722, 23, 147832.366, None, 0.7458632612789412)
# (213, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Others', 220.583, 24, 2194.815, None, 0.0111265198441339)
# (214, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Other renewables aggregated', 67.105, 25, 882.631, None, 0.0033848715183881)
# (215, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Low carbon', 5047.339, 26, 55322.628, None, 0.2545949485843035)
# (216, 'Republic of Turkiye', 'AUG2010', 'August 2010', 2010, 8, 'August', 'Fossil fuels', 14786.722, 27, 147832.366, None, 0.7458632612789412)
# (217, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Hydro', 3245.144, 1, 51423.001, None, 0.1960279315023626)
# (218, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Wind', 283.953, 2, 2908.0, None, 0.0171526191854322)
# (219, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (220, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Geothermal', 47.477, 4, 567.002, None, 0.0028679214555464)
# (221, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (222, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (223, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Total combustible fuels', 12968.841, 7, 148039.001, None, 0.7834028552240002)
# (224, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Coal', 4428.39, 8, 52332.776, None, 0.2675037322182769)
# (225, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Oil', 171.837, 9, 2072.51, None, 0.0103800791784806)
# (226, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Natural gas', 8342.008, 10, 93304.775, None, 0.5039118673365994)
# (227, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Combustible renewables', 25.53, 11, 315.629, None, 0.0015421790500684)
# (228, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Other combustible non-renewables', 1.077, 12, 13.309, None, 6.50578471180461e-05)
# (229, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Not specified', 9.083, 13, 108.996, None, 0.0005486726326585)
# (230, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Net electricity production', 16554.498, 14, 203046.001, None, 1.0)
# (231, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Total imports', 120.994, 15, 1144.001, None, 0.0073088292982366)
# (232, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Total exports', 178.217, 16, 1918.001, None, 0.0107654729246395)
# (233, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Electricity supplied', 16497.275, 17, 202272.001, None, 0.9965433563735971)
# (234, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (235, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Distribution losses', 2474.644, 19, 30222.0, None, 0.1494846899011978)
# (236, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Final consumption', 14022.631, 20, 172050.001, None, 0.8470586664723992)
# (237, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Electricity trade', 57.223, 21, 774.0, None, 0.0034566436264029)
# (238, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Renewables', 3602.104, 22, 55213.632, None, 0.2175906511934097)
# (239, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Non-renewables', 12952.395, 23, 147832.366, None, 0.7824094092131335)
# (240, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Others', 181.997, 24, 2194.815, None, 0.0109938096582572)
# (241, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Other renewables aggregated', 73.007, 25, 882.631, None, 0.0044101005056148)
# (242, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Low carbon', 3611.187, 26, 55322.628, None, 0.2181393238260683)
# (243, 'Republic of Turkiye', 'SEP2010', 'September 2010', 2010, 9, 'September', 'Fossil fuels', 12952.395, 27, 147832.366, None, 0.7824094092131335)
# (244, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Hydro', 3195.323, 1, 51423.001, None, 0.1934275307872812)
# (245, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Wind', 288.675, 2, 2908.0, None, 0.0174748194314059)
# (246, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (247, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Geothermal', 49.144, 4, 567.002, None, 0.002974911322896)
# (248, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (249, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (250, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Total combustible fuels', 12977.258, 7, 148039.001, None, 0.7855728423478602)
# (251, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Coal', 4157.314, 8, 52332.776, None, 0.2516612504361517)
# (252, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Oil', 170.73, 9, 2072.51, None, 0.0103350685772025)
# (253, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Natural gas', 8617.354, 10, 93304.775, None, 0.5216478916653813)
# (254, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Combustible renewables', 30.571, 11, 315.629, None, 0.0018506025975145)
# (255, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Other combustible non-renewables', 1.289, 12, 13.309, None, 7.802907161022705e-05)
# (256, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Not specified', 9.083, 13, 108.996, None, 0.000549835575978)
# (257, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Net electricity production', 16519.484, 14, 203046.001, None, 1.0)
# (258, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Total imports', 218.469, 15, 1144.001, None, 0.0132249288173892)
# (259, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Total exports', 244.412, 16, 1918.001, None, 0.0147953773858796)
# (260, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Electricity supplied', 16493.541, 17, 202272.001, None, 0.9984295514315096)
# (261, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (262, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Distribution losses', 2493.185, 19, 30222.0, None, 0.1509239029499952)
# (263, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Final consumption', 14000.357, 20, 172050.001, None, 0.8475057090160927)
# (264, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Electricity trade', 25.943, 21, 774.0, None, 0.0015704485684903)
# (265, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Renewables', 3563.713, 22, 55213.632, None, 0.2157278641390978)
# (266, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Non-renewables', 12955.77, 23, 147832.366, None, 0.7842720753263238)
# (267, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Others', 181.102, 24, 2194.815, None, 0.0109629332247907)
# (268, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Other renewables aggregated', 79.715, 25, 882.631, None, 0.0048255139204105)
# (269, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Low carbon', 3572.796, 26, 55322.628, None, 0.2162776997150758)
# (270, 'Republic of Turkiye', 'OCT2010', 'October 2010', 2010, 10, 'October', 'Fossil fuels', 12955.77, 27, 147832.366, None, 0.7842720753263238)
# (271, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Hydro', 3386.22, 1, 51423.001, None, 0.2151609755118112)
# (272, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Wind', 265.474, 2, 2908.0, None, 0.0168682616052774)
# (273, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (274, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Geothermal', 52.918, 4, 567.002, None, 0.0033624184199886)
# (275, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (276, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (277, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Total combustible fuels', 12024.382, 7, 148039.001, None, 0.7640312091496312)
# (278, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Coal', 4403.55, 8, 52332.776, None, 0.2798022909660437)
# (279, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Oil', 150.579, 9, 2072.51, None, 0.0095678144159543)
# (280, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Natural gas', 7438.308, 10, 93304.775, None, 0.4726313132157124)
# (281, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Combustible renewables', 30.652, 11, 315.629, None, 0.0019476331193448)
# (282, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Other combustible non-renewables', 1.293, 12, 13.309, None, 8.21574325757842e-05)
# (283, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Not specified', 9.083, 13, 108.996, None, 0.0005771353132914)
# (284, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Net electricity production', 15738.077, 14, 203046.001, None, 1.0)
# (285, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Total imports', 213.607, 15, 1144.001, None, 0.0135726238980785)
# (286, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Total exports', 236.451, 16, 1918.001, None, 0.0150241354137484)
# (287, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Electricity supplied', 15715.233, 17, 202272.001, None, 0.99854848848433)
# (288, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (289, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Distribution losses', 2371.293, 19, 30222.0, None, 0.1506723470726442)
# (290, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Final consumption', 13343.94, 20, 172050.001, None, 0.8478761414116859)
# (291, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Electricity trade', 22.844, 21, 774.0, None, 0.0014515115156699)
# (292, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Renewables', 3735.264, 22, 55213.632, None, 0.2373392886564223)
# (293, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Non-renewables', 12002.813, 23, 147832.366, None, 0.7626607113435778)
# (294, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Others', 160.955, 24, 2194.815, None, 0.0102271071618216)
# (295, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Other renewables aggregated', 83.57, 25, 882.631, None, 0.0053100515393335)
# (296, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Low carbon', 3744.347, 26, 55322.628, None, 0.2379164239697137)
# (297, 'Republic of Turkiye', 'NOV2010', 'November 2010', 2010, 11, 'November', 'Fossil fuels', 12002.813, 27, 147832.366, None, 0.7626607113435778)
# (298, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Hydro', 3553.654, 1, 51423.001, None, 0.1939712198156799)
# (299, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Wind', 377.064, 2, 2908.0, None, 0.0205815096316578)
# (300, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Solar', 0.0, 3, 0.0, None, 0.0)
# (301, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Geothermal', 54.234, 4, 567.002, None, 0.0029602868302551)
# (302, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Other renewables', 0.0, 5, 0.0, None, 0.0)
# (303, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Nuclear', 0.0, 6, 0.0, None, 0.0)
# (304, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Total combustible fuels', 14326.487, 7, 148039.001, None, 0.7819912009057383)
# (305, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Coal', 5001.0, 8, 52332.776, None, 0.2729725714147227)
# (306, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Oil', 191.711, 9, 2072.51, None, 0.010464276072483)
# (307, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Natural gas', 9103.44, 10, 93304.775, None, 0.4968985054028482)
# (308, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Combustible renewables', 29.108, 11, 315.629, None, 0.0015888193578763)
# (309, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Other combustible non-renewables', 1.227, 12, 13.309, None, 6.697407421033091e-05)
# (310, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Not specified', 9.083, 13, 108.996, None, 0.0004957828166686)
# (311, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Net electricity production', 18320.522, 14, 203046.001, None, 1.0)
# (312, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Total imports', 218.773, 15, 1144.001, None, 0.0119414173897446)
# (313, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Total exports', 218.522, 16, 1918.001, None, 0.0119277169067562)
# (314, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Electricity supplied', 18320.773, 17, 202272.001, None, 1.0000137004829883)
# (315, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Used for pumped storage', 0.0, 18, 0.0, None, 0.0)
# (316, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Distribution losses', 2758.416, 19, 30222.0, None, 0.1505642688565314)
# (317, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Final consumption', 15562.356, 20, 172050.001, None, 0.8494493770428593)
# (318, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Electricity trade', -0.251, 21, 774.0, None, -1.37004829884214e-05)
# (319, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Renewables', 4014.06, 22, 55213.632, None, 0.2191018356354693)
# (320, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Non-renewables', 14306.461, 23, 147832.366, None, 0.780898109780933)
# (321, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Others', 202.021, 24, 2194.815, None, 0.011027032963362)
# (322, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Other renewables aggregated', 83.342, 25, 882.631, None, 0.0045491061881315)
# (323, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Low carbon', 4023.143, 26, 55322.628, None, 0.219597618452138)
# (324, 'Republic of Turkiye', 'DEC2010', 'December 2010', 2010, 12, 'December', 'Fossil fuels', 14306.461, 27, 147832.366, None, 0.780898109780933)
# (325, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Hydro', 3074.65, 1, 51154.999, 4186.449, 0.1663882030268891)
# (326, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Wind', 255.785, 2, 4715.999, 240.631, 0.013842097966023)
# (327, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Solar', 0.0, 3, 0.0, 0.0, 0.0)
# (328, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Geothermal', 55.907, 4, 589.001, 45.985, 0.0030254712785599)
# (329, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Other renewables', 0.0, 5, 0.0, 0.0, 0.0)
# (330, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Nuclear', 0.0, 6, 0.0, 0.0, 0.0)
# (331, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Total combustible fuels', 15083.765, 7, 160994.0, 12348.644, 0.8162752031060069)
# (332, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Coal', 5647.97, 8, 62148.984, 4316.608, 0.3056463594392138)
# (333, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Oil', 92.097, 9, 848.464, 169.861, 0.004983934540246)
# (334, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Natural gas', 9312.86, 10, 97655.853, 7831.162, 0.5039760754690761)
# (335, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Combustible renewables', 29.139, 11, 321.929, 29.758, 0.0015768903283302)
# (336, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Other combustible non-renewables', 1.699, 12, 18.773, 1.255, 9.194332914077525e-05)
# (337, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Not specified', 8.667, 13, 104.004, 9.083, 0.0004690246225209)
# (338, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Net electricity production', 18478.774, 14, 217557.998, 16830.792, 1.0)
# (339, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Total imports', 339.772, 15, 4556.001, 62.229, 0.018387150576115)
# (340, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Total exports', 222.443, 16, 3645.0, 127.369, 0.0120377574832616)
# (341, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Electricity supplied', 18596.103, 17, 218468.999, 16765.652, 1.006349393092853)
# (342, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Used for pumped storage', 0.0, 18, 0.0, 0.0, 0.0)
# (343, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Distribution losses', 2757.662, 19, 32369.0, 2497.56, 0.149234034682171)
# (344, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Final consumption', 15838.442, 20, 186099.999, 14268.091, 0.8571154125268267)
# (345, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Electricity trade', -117.329, 21, -911.001, 65.14, -0.0063493930928534)
# (346, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Renewables', 3415.481, 22, 56781.928, 4502.823, 0.1848326625998023)
# (347, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Non-renewables', 15063.293, 23, 160776.078, 12327.969, 0.8151673374001975)
# (348, 'Republic of Turkiye', 'JAN2011', 'January 2011', 2011, 1, 'January', 'Others', 102.463, 24, 971.241, 180.199, 0.0055449024919077)
# ...
# (3996, 'Republic of Turkiye', 'AUG2022', 'August 2022', 2022, 8, 'August', 'Other renewables aggregated', 1270.872333, 25, 16594.17435, 9527.436735, 0.0414843275347804)
# (3997, 'Republic of Turkiye', 'AUG2022', 'August 2022', 2022, 8, 'August', 'Low carbon', 11235.987608, 26, 134811.760715, 81737.510528, 0.3667696416104186)
# (3998, 'Republic of Turkiye', 'AUG2022', 'August 2022', 2022, 8, 'August', 'Fossil fuels', 19523.003209, 27, 179285.576235, 130920.542309, 0.6372777489560206)
# (3999, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Hydro', 3919.899104, 1, 66745.246723, 45229.409087, 0.148072222072499)
# (4000, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Wind', 2476.187949, 2, 34840.424594, 22318.205791, 0.0935367574903718)
# (4001, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Solar', 1610.747586, 3, 15220.537346, 10858.187181, 0.0608451819623502)
# (4002, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Geothermal', 673.570428, 4, 8984.096788, 6508.370567, 0.0254437849929629)
# (4003, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Total combustible fuels', 17684.447248, 7, 185484.276096, 152683.211448, 0.6680211226516432)
# (4004, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Coal', 9608.453145, 8, 107701.832237, 71630.897725, 0.3629544970705556)
# (4005, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Oil', 12.218395, 9, 540.468303, 108.251374, 0.0004615437412568)
# (4006, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Natural gas', 7445.893993, 10, 69611.870073, 76708.324908, 0.281264910041874)
# (4007, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Combustible renewables', 615.791383, 11, 7610.077562, 4221.342475, 0.023261210555359)
# (4008, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Other combustible non-renewables', 2.090332, 12, 20.02792, 14.394969, 7.896124259764902e-05)
# (4009, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Not specified', 108.034018, 13, 1411.377702, 1021.403003, 0.0040809308301728)
# (4010, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Net electricity production', 26472.886333, 14, 312685.959248, 238618.787075, 1.0)
# (4011, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Total imports', 642.472518, 15, 6423.136452, 1302.125699, 0.0242690770442783)
# (4012, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Total exports', 291.617771, 16, 3709.514229, 3087.299903, 0.0110157149972906)
# (4013, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Electricity supplied', 26823.74108, 17, 315399.581471, 236833.612871, 1.0132533620469877)
# (4014, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Distribution losses', 2570.318753, 19, 30452.040659, 23624.192051, 0.0970925013868226)
# (4015, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Final consumption', 24253.422326, 20, 284947.540808, 213209.420816, 0.9161608606223904)
# (4016, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Electricity trade', -350.854747, 21, -2713.622223, 1785.174204, -0.0132533620469876)
# (4017, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Renewables', 9296.19645, 22, 133400.383013, 89135.515101, 0.3511591570735431)
# (4018, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Non-renewables', 17176.689883, 23, 179285.576235, 149483.271979, 0.6488408429264568)
# (4019, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Others', 122.342745, 24, 1971.873925, 1144.049346, 0.0046214358140272)
# (4020, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Other renewables aggregated', 1289.361811, 25, 16594.17435, 10729.713042, 0.048704995548322)
# (4021, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Low carbon', 9404.230468, 26, 134811.760715, 90156.918104, 0.3552400879037159)
# (4022, 'Republic of Turkiye', 'SEP2022', 'September 2022', 2022, 9, 'September', 'Fossil fuels', 17176.689883, 27, 179285.576235, 149483.271979, 0.6488408429264568)
# (4023, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Hydro', 3271.387047, 1, 66745.246723, 48469.809856, 0.1342446820621256)
# (4024, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Wind', 3198.237994, 2, 34840.424594, 24957.232859, 0.1312429365572225)
# (4025, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Solar', 1261.086719, 3, 15220.537346, 12102.840041, 0.051749971254601)
# (4026, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Geothermal', 753.117989, 4, 8984.096788, 7298.698068, 0.0309049597421642)
# (4027, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Total combustible fuels', 15775.058605, 7, 185484.276096, 169943.92673, 0.647345513237775)
# (4028, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Coal', 10167.472518, 8, 107701.832237, 77964.588971, 0.4172325365187245)
# (4029, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Oil', 10.367731, 9, 540.468303, 159.861686, 0.0004254503462306)
# (4030, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Natural gas', 4985.610615, 10, 69611.870073, 87047.081132, 0.2045895830363461)
# (4031, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Combustible renewables', 609.260061, 11, 7610.077562, 4756.491098, 0.0250016039089905)
# (4032, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Other combustible non-renewables', 2.34768, 12, 20.02792, 15.903844, 9.63394274831006e-05)
# (4033, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Not specified', 109.95067, 13, 1411.377702, 1154.527991, 0.0045119371461116)
# (4034, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Net electricity production', 24368.839024, 14, 312685.959248, 263927.035543, 1.0)
# (4035, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Total imports', 702.282765, 15, 6423.136452, 1664.92144, 0.028818884818778)
# (4036, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Total exports', 287.192488, 16, 3709.514229, 3501.246236, 0.0117852347301877)
# (4037, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Electricity supplied', 24783.929301, 17, 315399.581471, 262090.710747, 1.01703365008859)
# (4038, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Distribution losses', 2370.839683, 19, 30452.040659, 26158.051948, 0.0972898085405318)
# (4039, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Final consumption', 22413.089618, 20, 284947.540808, 235932.658795, 0.9197438415480584)
# (4040, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Electricity trade', -415.090277, 21, -2713.622223, 1836.324796, -0.0170336500885902)
# (4041, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Renewables', 9093.08981, 22, 133400.383013, 97585.071922, 0.3731441535251039)
# (4042, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Non-renewables', 15275.749214, 23, 179285.576235, 166341.963624, 0.626855846474896)
# (4043, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Others', 122.666081, 24, 1971.873925, 1330.293521, 0.0050337269198253)
# (4044, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Other renewables aggregated', 1362.37805, 25, 16594.17435, 12055.189166, 0.0559065636511547)
# (4045, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Low carbon', 9203.04048, 26, 134811.760715, 98739.599913, 0.3776560906712155)
# (4046, 'Republic of Turkiye', 'OCT2022', 'October 2022', 2022, 10, 'October', 'Fossil fuels', 15275.749214, 27, 179285.576235, 166341.963624, 0.626855846474896)
# (4047, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Hydro', 3144.55956, 1, 66745.246723, 51544.554185, 0.1319468348509702)
# (4048, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Wind', 2965.270269, 2, 34840.424594, 27560.236903, 0.124423792587422)
# (4049, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Solar', 909.600388, 3, 15220.537346, 12931.315162, 0.0381671550135353)
# (4050, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Geothermal', 768.165987, 4, 8984.096788, 8078.001452, 0.0322325173655866)
# (4051, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Total combustible fuels', 15916.983141, 7, 185484.276096, 187837.207556, 0.66788226006163)
# (4052, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Coal', 10497.876104, 8, 107701.832237, 87190.460779, 0.4404946060491966)
# (4053, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Oil', 11.941209, 9, 540.468303, 314.741106, 0.0005010573664707)
# (4054, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Natural gas', 4748.020973, 10, 69611.870073, 95008.07748, 0.1992286446606131)
# (4055, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Combustible renewables', 658.498994, 11, 7610.077562, 5306.53021, 0.0276308514286331)
# (4056, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Other combustible non-renewables', 0.645861, 12, 20.02792, 17.397982, 2.7100556716337883e-05)
# (4057, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Not specified', 127.440299, 13, 1411.377702, 1285.063757, 0.005347440162816)
# (4058, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Net electricity production', 23832.019643, 14, 312685.959248, 289236.379013, 1.0)
# (4059, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Total imports', 743.02029, 15, 6423.136452, 1963.341173, 0.0311773949975843)
# (4060, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Total exports', 241.566877, 16, 3709.514229, 3855.88983, 0.0101362318686638)
# (4061, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Electricity supplied', 24333.473056, 17, 315399.581471, 287343.830356, 1.0210411631289205)
# (4062, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Distribution losses', 2326.729306, 19, 30452.040659, 28708.066251, 0.0976303872208083)
# (4063, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Final consumption', 22006.743749, 20, 284947.540808, 258635.764101, 0.9234107758661518)
# (4064, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Electricity trade', -501.453413, 21, -2713.622223, 1892.548657, -0.0210411631289204)
# (4065, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Renewables', 8446.095198, 22, 133400.383013, 105420.637912, 0.3544011512461475)
# (4066, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Non-renewables', 15385.924446, 23, 179285.576235, 183815.741104, 0.645598848795813)
# (4067, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Others', 140.027369, 24, 1971.873925, 1617.202845, 0.0058755980860031)
# (4068, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Other renewables aggregated', 1426.664981, 25, 16594.17435, 13384.531662, 0.0598633687942198)
# (4069, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Low carbon', 8573.535497, 26, 134811.760715, 106705.701669, 0.3597485914089636)
# (4070, 'Republic of Turkiye', 'NOV2022', 'November 2022', 2022, 11, 'November', 'Fossil fuels', 15385.924446, 27, 179285.576235, 183815.741104, 0.645598848795813)
# (4071, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Hydro', 3288.088307, 1, 66745.246723, 55175.539304, 0.1300602503168889)
# (4072, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Wind', 2612.560655, 2, 34840.424594, 31029.880067, 0.1033397710256068)
# (4073, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Solar', 732.787559, 3, 15220.537346, 13547.276061, 0.0289853934730841)
# (4074, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Geothermal', 818.859717, 4, 8984.096788, 8915.711914, 0.0323899755188165)
# (4075, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Total combustible fuels', 17730.410537, 7, 185484.276096, 206596.468274, 0.7013259430271821)
# (4076, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Coal', 10832.500239, 8, 107701.832237, 96988.236906, 0.4284792746115561)
# (4077, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Oil', 11.706242, 9, 540.468303, 496.185022, 0.0004630401080009)
# (4078, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Natural gas', 6174.88176, 10, 69611.870073, 103224.141196, 0.2442472927728433)
# (4079, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Combustible renewables', 710.398333, 11, 7610.077562, 5868.322643, 0.0280997882015462)
# (4080, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Other combustible non-renewables', 0.923963, 12, 20.02792, 19.582507, 3.654733323545853e-05)
# (4081, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Not specified', 98.563244, 13, 1411.377702, 1404.992711, 0.0038986666384214)
# (4082, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Net electricity production', 25281.270019, 14, 312685.959248, 316669.868328, 1.0)
# (4083, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Total imports', 725.325798, 15, 6423.136452, 2330.499761, 0.0286902437043267)
# (4084, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Total exports', 261.106713, 16, 3709.514229, 4186.477775, 0.010328069468178)
# (4085, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Electricity supplied', 25745.489104, 17, 315399.581471, 314813.890314, 1.0183621742361486)
# (4086, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Distribution losses', 2462.98955, 19, 30452.040659, 31486.577626, 0.0974234897277294)
# (4087, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Final consumption', 23282.499554, 20, 284947.540808, 283327.312684, 0.9209386845084192)
# (4088, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Electricity trade', -464.219085, 21, -2713.622223, 1855.978014, -0.0183621742361486)
# (4089, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Renewables', 8162.694571, 22, 133400.383013, 114536.729989, 0.3228751785359426)
# (4090, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Non-renewables', 17118.575448, 23, 179285.576235, 202133.138342, 0.6771248214640573)
# (4091, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Others', 111.193449, 24, 1971.873925, 1920.76024, 0.0043982540796579)
# (4092, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Other renewables aggregated', 1529.25805, 25, 16594.17435, 14784.034557, 0.0604897637203627)
# (4093, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Low carbon', 8261.257815, 26, 134811.760715, 115941.7227, 0.3267738451743642)
# (4094, 'Republic of Turkiye', 'DEC2022', 'December 2022', 2022, 12, 'December', 'Fossil fuels', 17118.575448, 27, 179285.576235, 202133.138342, 0.6771248214640573)

# %% [markdown]
# ## Resources
# - PostgreSQL Documentation: https://www.postgresql.org/docs/16/index.html

# %% [markdown]
# ## Shortcuts
# - \l: List of Databases in SQL Shell

# %% [markdown]
# ## Open Datasets
# - https://registry.opendata.aws
# - https://datasetsearch.research.google.com
# - https://archive.ics.uci.edu/datasets
# - https://www.kaggle.com/datasets

# %% [markdown]
# ## Some Discussions
# **- Advantages of RDBMS (Relational Database Management System):**
#
# **Data Integrity:** RDBMS ensures data integrity through the use of constraints (such as primary keys, foreign keys, unique constraints) and normalization techniques. This helps maintain accuracy and consistency in the data.
# **Data Security:** RDBMS systems provide robust security features, allowing for user authentication and authorization. Access to data can be restricted at various levels, ensuring that only authorized users can manipulate specific data.
# **Data Independence:** RDBMS allows for data independence, separating the logical structure of the database from its physical storage. This means changes to the database structure (schema) do not affect the application programs.
# **Data Retrieval:** RDBMS supports SQL (Structured Query Language) for querying and retrieving data, making it easy to interact with the database. SQL provides a standardized way to manage and retrieve data, regardless of the specific RDBMS implementation.
# **Concurrency Control:** RDBMS systems implement concurrency control mechanisms to ensure that multiple users can access and modify the data simultaneously without conflicting with each other.
# **Scalability:** RDBMS systems can scale vertically (by adding more powerful hardware) or horizontally (by adding more servers) to handle increased loads and growing data volumes.
#
# **- ACID Properties:**
#
# ACID is an acronym that stands for Atomicity, Consistency, Isolation, and Durability. These properties ensure the reliability of transactions in a database:
#
# **Atomicity:** Ensures that a transaction is treated as a single, indivisible unit. Either all the changes within a transaction are committed to the database, or none of them are.
# **Consistency:** Guarantees that a transaction brings the database from one valid state to another. The database should satisfy certain integrity constraints before and after the transaction.
# **Isolation:** Ensures that the execution of a transaction is isolated from other transactions. Even though multiple transactions may be executed concurrently, the outcome should be as if they were executed serially.
# **Durability:** Guarantees that once a transaction is committed, its changes are permanent and survive any subsequent failures. The changes are stored in the database and will persist, even in the case of a system crash or power loss.
#
# **- When not to use a Relational Database:**
#
# **Unstructured or Semi-Structured Data:** If your data is inherently unstructured or semi-structured (like JSON or XML documents) and does not fit well into tables with predefined schemas, a NoSQL database might be a better fit.
# **High Volume and Low-Latency Requirements:** In cases where extremely high write or read throughput with low-latency response times is crucial, some NoSQL databases, like key-value stores or document databases, may be more suitable than traditional RDBMS.
# **Scalability Demands:** If your application requires easy horizontal scalability and the ability to distribute data across multiple servers or clusters, NoSQL databases may offer better scalability options compared to traditional RDBMS.
# **Flexible Schema Requirements:** When the structure of your data is expected to evolve frequently or is not well-defined in advance, NoSQL databases with schema flexibility may be more appropriate.
# **Cost and Simplicity:** For simpler applications or projects with budget constraints, a lightweight database system or NoSQL solution might be a more cost-effective and simpler choice compared to a full-fledged RDBMS.
